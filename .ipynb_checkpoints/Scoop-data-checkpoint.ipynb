# %% [markdown]
# # Data to Dataframe

# %%
import pandas as pd

# %%
scoop = pd.read_excel("IPOScoop-Dataset.xls")

# %%
overview = scoop[3:24]
overview = overview.drop(columns=['Unnamed: 6', 
                                  'Unnamed: 7', 
                                  'Unnamed: 8', 
                                  'Unnamed: 9', 
                                  'Unnamed: 10', 
                                  'Unnamed: 11'])
overview.rename(columns={'Unnamed: 0': 'Date', 
                         'Unnamed: 1': 'IPOs Priced',
                         'Unnamed: 2': 'Calls',
                         'IPO SCOOP Rating Scorecard': 'On Target',
                         'Unnamed: 4': 'Missed',
                         'Unnamed: 5': 'Batting Average'
                        }, inplace=True)

overview['Date'] = overview['Date'].astype('int32')
overview['IPOs Priced'] = overview['IPOs Priced'].astype('int32')
overview['Calls'] = overview['Calls'].astype('int32')
overview['On Target'] = overview['On Target'].astype('int32')
overview['Missed'] = overview['Missed'].astype('int32')
overview['Batting Average'] = overview['Batting Average'].astype('float32')
overview = overview.set_index('Date')
overview
# Out:
#       IPOs Priced  Calls  On Target  Missed  Batting Average
# Date
# 2020          205    198        180      18         0.909091
# 2019          231    207        186      21         0.898551
# 2018          228    223        191      32         0.856502
# 2017          186    182        157      25         0.862637
# 2016          107    106         97       9         0.915094
# 2015          173    173        157      16         0.907514
# 2014          261    261        234      27         0.896552
# 2013          230    230        209      21         0.908696
# 2012          146    146        134      12         0.917808
# 2011          143    143        130      13         0.909091
# 2010          165    160        142      18         0.887500
# 2009           63     61         50      11         0.819672
# 2008           50     47         43       4         0.914894
# 2007          279    256        230      26         0.898438
# 2006          240    237        212      25         0.894515
# 2005          236    226        198      28         0.876106
# 2004          249    232        201      31         0.866379
# 2003           84     80         70      10         0.875000
# 2002           85     83         70      13         0.843373
# 2001           96     94         78      16         0.829787
# 2000          256    237        210      27         0.886076

# %%
def get_data(year, start, end):
    name = scoop[start:end]
    name = name.drop(columns=['Unnamed: 11'])
    name.rename(columns={'Unnamed: 0': 'Trade Date', 
                             'Unnamed: 1': 'Company',
                             'Unnamed: 2': 'Ticker',
                             'IPO SCOOP Rating Scorecard': 'Lead/Joint-Lead Mangers',
                             'Unnamed: 4': 'Offer Price',
                             'Unnamed: 5': 'Opening Price',
                             'Unnamed: 6': '1st Day Close',
                             'Unnamed: 7': '1st Day Percent Change',
                             'Unnamed: 8': 'Change Opening',
                             'Unnamed: 9': 'Change Close',
                             'Unnamed: 10': 'Star Ratings'
                            }, inplace=True)
    name['Trade Date'] = name['Trade Date'].astype('datetime64')
    name['Company'] = name['Company'].astype(str)
    name['Ticker'] = name['Ticker'].astype(str)
    name['Lead/Joint-Lead Mangers'] = name['Lead/Joint-Lead Mangers'].str.split('/ ').astype(str)
    name['Offer Price'] = name['Offer Price'].astype('float32')
    name['Opening Price'] = name['Opening Price'].astype('float32')
    name['1st Day Close'] = name['1st Day Close'].astype('float64')
    name['1st Day Percent Change'] = name['1st Day Percent Change'].astype('float32')
    name['Change Opening'] = name['Change Opening'].astype('float32')
    name['Change Close'] = name['Change Close'].astype('float32')
    name['Year'] = year
    name = name.set_index('Ticker')
    return name

# %%
ipos_2020 = get_data(2020, 36, 241)
ipos_2019 = get_data(2019, 246, 467)
ipos_2018 = get_data(2018, 472, 701)
ipos_2017 = get_data(2017, 706, 887)
ipos_2016 = get_data(2016, 892, 998)
ipos_2015 = get_data(2015, 1003, 1176)
ipos_2014 = get_data(2014, 1181, 1469)
ipos_2013 = get_data(2013, 1474, 1704)
# ipos_2012 = get_data(2012, 1709, 1855)
ipos_2011 = get_data(2011, 1861, 2004)
ipos_2010 = get_data(2010, 2009, 2169)
ipos_2009 = get_data(2009, 2174, 2235)
ipos_2008 = get_data(2008, 2240, 2287)
ipos_2007 = get_data(2007, 2292, 2548)
ipos_2006 = get_data(2006, 2553, 2790)
ipos_2005 = get_data(2005, 2795, 3021)
ipos_2004 = get_data(2004, 3026, 3259)
ipos_2003 = get_data(2003, 3264, 3344)
ipos_2002 = get_data(2002, 3349, 3431)
ipos_2001 = get_data(2001, 3436, 3530)
ipos_2000 = get_data(2000, 3535, 3772)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /var/folders/8s/x__k3qxs3lbgfsdfz_rp19qw0000gn/T/ipykernel_56661/1561995772.py in <module>
#       7 ipos_2014 = get_data(2014, 1181, 1469)
#       8 ipos_2013 = get_data(2013, 1474, 1704)
# ----> 9 ipos_2012 = get_data(2012, 1709, 1855)
#      10 ipos_2011 = get_data(2011, 1861, 2004)
#      11 ipos_2010 = get_data(2010, 2009, 2169)
#
# /var/folders/8s/x__k3qxs3lbgfsdfz_rp19qw0000gn/T/ipykernel_56661/1498468491.py in get_data(year, start, end)
#      14                              'Unnamed: 10': 'Star Ratings'
#      15                             }, inplace=True)
# ---> 16     name['Trade Date'] = name['Trade Date'].astype('datetime64')
#      17     name['Company'] = name['Company'].astype(str)
#      18     name['Ticker'] = name['Ticker'].astype(str)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1181
#    1182             return astype_nansafe(
# -> 1183                 to_datetime(arr).values,
#    1184                 dtype,
#    1185                 copy=copy,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     897     elif is_list_like(arg):
#     898         try:
# --> 899             cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     900         except OutOfBoundsDatetime:
#     901             # caching attempts to create a DatetimeIndex, which may raise
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     193         unique_dates = unique(arg)
#     194         if len(unique_dates) < len(arg):
# --> 195             cache_dates = convert_listlike(unique_dates, format)
#     196             cache_array = Series(cache_dates, index=unique_dates)
#     197             # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 120-11-01 00:00:00

# %%
frames = [ipos_2000, ipos_2001, ipos_2002, ipos_2003, ipos_2004, 
          ipos_2005, ipos_2006, ipos_2007, ipos_2008, ipos_2009, 
          ipos_2010, ipos_2011, ipos_2012, ipos_2013, ipos_2014, 
          ipos_2015, ipos_2016, ipos_2017, ipos_2018, ipos_2019,
          ipos_2020]
ipos = pd.concat(frames)
# Out:
#        Trade Date                         Company  \
# Ticker
# IMAB   2020-01-17                          I-Mab
# LIZI   2020-01-17                          LIZHI
# DNK    2020-01-17     Phoenix Tree Holdings Ltd.
# VEL    2020-01-17             Velocity Financial
# GHIVU  2020-01-24              Gores Holdings IV
# ...           ...                             ...
# SVACU  2020-09-10    Starboard Value Acquisition
# BSN.U  2020-09-11         Broadstone Acquisition
# LEAP.U 2020-09-11                    Ribbit LEAP
# SNPR.U 2020-09-11  Tortoise Acquisition Corp. II
# TWCTU  2020-09-11           TWC Tech Holdings II
#
#                                   Lead/Joint-Lead Mangers  Offer Price  \
# Ticker
# IMAB                                ['Jefferies', 'CICC']         14.0
# LIZI                       ['Credit Suisse', 'Citigroup']         11.0
# DNK         ['Citigroup', 'Credit Suisse', 'J.P. Morgan']         13.5
# VEL     ['Wells Fargo Securities', 'Citigroup', 'JMP S...         13.0
# GHIVU                        ['Deutsche Bank Securities']         10.0
# ...                                                   ...          ...
# SVACU          ['UBS Investment Bank', 'Stifel', 'Cowen']         10.0
# BSN.U                                       ['Citigroup']         10.0
# LEAP.U                                       ['JPMorgan']         10.0
# SNPR.U                      ['Barclays', 'Goldman Sachs']         10.0
# TWCTU           ['Citigroup', 'Deutsche Bank Securities']         10.0
#
#         Opening Price  1st Day Close  1st Day Percent Change  Change Opening  \
# Ticker
# IMAB            14.75         12.750               -0.089286            0.75
# LIZI            11.03         11.630                0.057273            0.03
# DNK             13.50         13.500                0.000000            0.00
# VEL             13.85         13.510                0.039231            0.85
# GHIVU           10.52         10.450                0.045000            0.52
# ...               ...            ...                     ...             ...
# SVACU           10.00         10.000                0.000000            0.00
# BSN.U            9.84          9.600               -0.040000           -0.16
# LEAP.U          11.20         11.553                0.155300            1.20
# SNPR.U          10.35         10.510                0.051000            0.35
# TWCTU           10.08         10.070                0.007000            0.08
#
#         Change Close Star Ratings    Year
# Ticker
# IMAB          -1.250            2  2020.0
# LIZI           0.630            1  2020.0
# DNK            0.000            1  2020.0
# VEL            0.510            1  2020.0
# GHIVU          0.450            1  2020.0
# ...              ...          ...     ...
# SVACU          0.000            1  2020.0
# BSN.U         -0.400            1  2020.0
# LEAP.U         1.553            1  2020.0
# SNPR.U         0.510            1  2020.0
# TWCTU          0.070            1  2020.0
#
# [205 rows x 11 columns]
